# %% [markdown]
# # Data Science Template

# %%
# Packages
import os
import pandas as pd
import numpy as nu
import matplotlib.pyplot as plt 
import seaborn as sea
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.linear_model import LinearRegression #Linear Models
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

# %%
# Data review
.head()
.describe()
.info()

# %% [markdown]
# ## Hypothesis

# %%
# Fill missing value 
.fillna(0)
.fillna(.mean())

# %% [markdown]
# ## Changes made, errors explained, feature selection explained

# %%
# Encoding
encode = LabelEncoder()
encode_2 = OneHotEncoder()

# %%
# Scaler 
scale = StandardScaler()

# %%
X = null
y = null

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=1/3, random_state=42)

# %%
# Model Implementation
model = LinearRegression()

model.fit(X_train,y_train)

prediction = model.predict(X_test)

# %%
# Model Metrics 
print(f'Model Accuracy : {accuracy_score(y_true=,y_pred=)}')

print(f'Model Precision Score : {precision_score(y_true=,y_pred=)}')

print(f'Model Recall Score : {recall_score(y_true=,y_pred=)}')

print(f'Model ROC-AUC : {roc_auc_score(y_true=,y_score=)}')

# %%
# Data visualizations
fig, ax= plt.subplots()#(row,column)
plt.figure(figsize=(0,0))
.set_xlable('')
.grid(True,alpha=0.3)

# %% [markdown]
# ## Review result of analysis
